# %%
import torch
import whisper
import json
from pathlib import Path
import numpy as np
import os 
from model_loader import load_model_simple, WhisperModelLoader
import wave 
import whisper

# %%
def get_wav_length(path):
    with wave.open(path, 'r') as wf:
        frames = wf.getnframes()
        rate = wf.getframerate()
        return frames / float(rate)

# %%
# load the fine tuned model 

checkpoint_dir = 'whisper-torgo-finetuned/best_model_epoch_7_wer_0.2290/'
model = load_model_simple(checkpoint_dir)

# %%
# Out:
# 50257

# %%
audio_dir_path = os.path.expanduser("~/torgo_data/M02/Session1/wav_headMic")
second_path = os.path.expanduser("~/torgo_data/M02/Session1/wav_headMic")
file_lists = [f for f in os.listdir(audio_dir_path) if os.path.isfile(os.path.join(audio_dir_path, f))]
second_list = [f for f in os.listdir(second_path) if os.path.isfile(os.path.join(second_path, f))]

# %%
def finetuned_infer(audio_dir_path, audio_file, prompt_path):
    audio_path = Path(audio_file)
    txt_file = audio_path.with_suffix('.txt')

    print(audio_file)
    result = WhisperModelLoader.transcribe_with_finetuned_model(
        model, 
        os.path.join(audio_dir_path, audio_path),
        language='en',
        beam_size = 5
    )
    with open(os.path.join(prompt_path, txt_file)) as txt_file: 
        contents = txt_file.read()
        print(f"Transcribed: {result.text}, Ground Truth: {contents}")

# %%
def infer(audio_dir_path, audio_file, prompt_path):
    if prompt_path is None:
        pass
    else:
        audio_path = Path(audio_file)
        txt_file = audio_path.with_suffix(".txt")
        
        print(audio_file)
        audio = whisper.load_audio(os.path.join(audio_dir_path, audio_file))
        audio = whisper.pad_or_trim(audio)
        mel = whisper.log_mel_spectrogram(audio, n_mels=model.dims.n_mels).to(model.device)
        _, probs = model.detect_language(mel)
    
        
        options = whisper.DecodingOptions()
        result = whisper.decode(model, mel, options)
    
        # print the recognized text
        with open(os.path.join(prompt_path, txt_file)) as txt_file: 
            contents = txt_file.read()
            print(f"Transcribed: {result.text}, Ground Truth: {contents}")

# %%
prompt_path = os.path.expanduser("~/torgo_data/M02/Session1/prompts")

for index, f in enumerate(file_lists):
    print(f"index: {index}")
    finetuned_infer(audio_dir_path, f, prompt_path)
# Out:
# index: 0
# 0013.wav
# Transcribed: I liked the wash and dishes and the guy putting away the dishes and falling off his stool., Ground Truth: input/images/kitchen.jpg
# index: 1
# 0137.wav
# Transcribed: Everything went real smooth, the sheriff said., Ground Truth: Everything went real smooth, the sheriff said.
# index: 2
# 0220.wav
# Transcribed: freedom, Ground Truth: fear
# index: 3
# 0130.wav
# Transcribed: I tried to tell people in the community,, Ground Truth: I tried to tell people in the community.
# index: 4
# 0227.wav
# Transcribed: much, Ground Truth: much
# index: 5
# 0068.wav
# Transcribed: floor, Ground Truth: floor
# index: 6
# 0014.wav
# Transcribed: tiger, Ground Truth: dagger
# index: 7
# 0229.wav
# Transcribed: Shh., Ground Truth: [relax your mouth in its normal position]
# index: 8
# 0066.wav
# Transcribed: yet he still thinks that swiftly as ever., Ground Truth: yet he still thinks as swiftly as ever.
# index: 9
# 0142.wav
# Transcribed: whoop, Ground Truth: whoop
# index: 10
# 0193.wav
# Transcribed: go, Ground Truth: though
# index: 11
# 0145.wav
# Transcribed: I droop., Ground Truth: droop
# index: 12
# 0194.wav
# Transcribed: Tear, Ground Truth: tear [as in "tear in my eye"]
# index: 13
# 0139.wav
# Transcribed: Blight, Ground Truth: write
# index: 14
# 0061.wav
# Transcribed: BING, Ground Truth: beat
# index: 15
# 0170.wav
# Transcribed: pay, Ground Truth: pay
# index: 16
# 0028.wav
# Transcribed: gadget, Ground Truth: gadget
# index: 17
# 0054.wav
# Transcribed: trout, Ground Truth: trait
# index: 18
# 0085.wav
# Transcribed: fill, Ground Truth: fee
# index: 19
# 0053.wav
# Transcribed: struggle, Ground Truth: stubble
# index: 20
# 0082.wav
# Transcribed: Ahhh, Ground Truth: [say 'Ah' for 5 seconds]
# index: 21
# 0177.wav
# Transcribed: Wurf, Ground Truth: witch
# index: 22
# 0212.wav
# Transcribed: for, Ground Truth: four
# index: 23
# 0105.wav
# Transcribed: jacket, Ground Truth: jacket
# index: 24
# 0179.wav
# Transcribed: near, Ground Truth: near
# index: 25
# 0021.wav
# Transcribed: parvo, Ground Truth: bubble
# index: 26
# 0026.wav
# Transcribed: write, Ground Truth: raid
# index: 27
# 0215.wav
# Transcribed: I looked after noticed short men., Ground Truth: I looked up and noticed two old men.
# index: 28
# 0102.wav
# Transcribed: error, Ground Truth: air
# index: 29
# 0037.wav
# Transcribed: Ahh, Ground Truth: [say 'Ah' for 5 seconds]
# index: 30
# 0113.wav
# Transcribed: corn, Ground Truth: corn
# index: 31
# 0204.wav
# Transcribed: urgent, Ground Truth: urgent
# index: 32
# 0114.wav
# Transcribed: spark, Ground Truth: spark
# index: 33
# 0203.wav
# Transcribed: She is thinner than I am., Ground Truth: She is thinner than I am.
# index: 34
# 0030.wav
# Transcribed: torn, Ground Truth: torn
# index: 35
# 0168.wav
# Transcribed: If you destroy confidence banks, you do something to the economy, he said., Ground Truth: If you destroy confidence in banks, you do something to the economy, he said.
# index: 36
# 0093.wav
# Transcribed: Tharg, Ground Truth: dug
# index: 37
# 0042.wav
# Transcribed: Tip, Ground Truth: tip
# index: 38
# 0166.wav
# Transcribed: single, Ground Truth: single
# index: 39
# 0039.wav
# Transcribed: stairs, Ground Truth: sticks
# index: 40
# 0161.wav
# Transcribed: not, Ground Truth: mut
# index: 41
# 0094.wav
# Transcribed: storm, Ground Truth: storm
# index: 42
# 0045.wav
# Transcribed: left, Ground Truth: yes
# index: 43
# 0185.wav
# Transcribed: He will not allow or very lie., Ground Truth: He will allow a rare lie.
# index: 44
# 0154.wav
# Transcribed: The islands are sparsely populated., Ground Truth: The islands are sparsely populated.
# index: 45
# 0070.wav
# Transcribed: boom, Ground Truth: weed
# index: 46
# 0128.wav
# Transcribed: madam, Ground Truth: menu
# index: 47
# 0077.wav
# Transcribed: range, Ground Truth: range
# index: 48
# 0238.wav
# Transcribed: The train of arms said to fall slowly., Ground Truth: The train approached the depot slowly.
# index: 49
# 0182.wav
# Transcribed: galore, Ground Truth: galore
# index: 50
# 0153.wav
# Transcribed: you, Ground Truth: xxx
#
# index: 51
# 0079.wav
# Transcribed: stew, Ground Truth: stick
# index: 52
# 0236.wav
# Transcribed: I scrubbed the floors thoroughly., Ground Truth: I scrubbed the floors thoroughly.
# index: 53
# 0121.wav
# Transcribed: She wished to know all of them by grandfather., Ground Truth: You wished to know all about my grandfather.
# index: 54
# 0005.wav
# Transcribed: home, Ground Truth: [say 'OA' as in cOAt in a very low pitch]
# index: 55
# 0002.wav
# Transcribed: Okay., Ground Truth: [relax your mouth in its normal position]
# index: 56
# 0231.wav
# Transcribed: rock, Ground Truth: rock
# index: 57
# 0126.wav
# Transcribed: I just try to do my best., Ground Truth: I just try to do my best.
# index: 58
# 0027.wav
# Transcribed: law, Ground Truth: the
# index: 59
# 0214.wav
# Transcribed: Delta, Ground Truth: delta
# index: 60
# 0103.wav
# Transcribed: I can read., Ground Truth: I can read
# index: 61
# 0213.wav
# Transcribed: steer, Ground Truth: peer
# index: 62
# 0104.wav
# Transcribed: air, Ground Truth: air
# index: 63
# 0178.wav
# Transcribed: share, Ground Truth: shear
# index: 64
# 0020.wav
# Transcribed: God causes us to be smarter in his language., Ground Truth: Grandfather likes to be modern in his language.
# index: 65
# 0052.wav
# Transcribed: kid looking at a basket of toys,, Ground Truth: input/images/story_starters_15.jpg
# index: 66
# 0083.wav
# Transcribed: Darbo, Ground Truth: double
# index: 67
# 0176.wav
# Transcribed: My wife and I are yellow lily., Ground Truth: Will Robin wear a yellow lily?
# index: 68
# 0171.wav
# Transcribed: cheer, Ground Truth: cheer
# index: 69
# 0029.wav
# Transcribed: run, Ground Truth: one
# index: 70
# 0055.wav
# Transcribed: She had your dark suit in which was water all year., Ground Truth: She had your dark suit in greasy wash water all year.
# index: 71
# 0084.wav
# Transcribed: thumb, Ground Truth: down
# index: 72
# 0144.wav
# Transcribed: drop, Ground Truth: drop
# index: 73
# 0195.wav
# Transcribed: floor, Ground Truth: floor
# index: 74
# 0138.wav
# Transcribed: eight, Ground Truth: ate
# index: 75
# 0060.wav
# Transcribed: snip, Ground Truth: slip
# index: 76
# 0228.wav
# Transcribed: No., Ground Truth: know
# index: 77
# 0067.wav
# Transcribed: Use the minus several buttons., Ground Truth: usually minus several buttons;
# index: 78
# 0143.wav
# Transcribed: gnome, Ground Truth: no
# index: 79
# 0192.wav
# Transcribed: through, Ground Truth: through
# index: 80
# 0131.wav
# Transcribed: Thigh, Ground Truth: sigh
# index: 81
# 0226.wav
# Transcribed: Mother sews yellow gingham aprons., Ground Truth: Mother sews yellow gingham aprons.
# index: 82
# 0069.wav
# Transcribed: train, Ground Truth: train
# index: 83
# 0015.wav
# Transcribed: rain, Ground Truth: rain
# index: 84
# 0012.wav
# Transcribed: sip, Ground Truth: sip
# index: 85
# 0136.wav
# Transcribed: Sheer, Ground Truth: hear
# index: 86
# 0221.wav
# Transcribed: bark, Ground Truth: back
# index: 87
# 0003.wav
# Transcribed: I feel, Ground Truth: [say 'Ah-P-Eee' repeatedly]
# index: 88
# 0230.wav
# Transcribed: rock, Ground Truth: rock
# index: 89
# 0127.wav
# Transcribed: False figures will go high in later years., Ground Truth: Both figures would go higher in later years.
# index: 90
# 0078.wav
# Transcribed: slip, Ground Truth: sip
# index: 91
# 0237.wav
# Transcribed: thigh, Ground Truth: thigh
# index: 92
# 0120.wav
# Transcribed: Trade, Ground Truth: trade
# index: 93
# 0004.wav
# Transcribed: Yee-P-Ah, Ground Truth: [say 'Eee-P-Ah' repeatedly]
# index: 94
# 0076.wav
# Transcribed: ripe, Ground Truth: right
# index: 95
# 0239.wav
# Transcribed: jurr, Ground Truth: deer
# index: 96
# 0183.wav
# Transcribed: Price and time shimmers on the ocean., Ground Truth: Bright sunshine shimmers on the ocean.
# index: 97
# 0152.wav
# Transcribed: You'd be better off taking a cold shower., Ground Truth: You'd be better off taking a cold shower.
# index: 98
# 0184.wav
# Transcribed: We gathered shells on the beach., Ground Truth: We gathered shells on the beach.
# index: 99
# 0155.wav
# Transcribed: knot, Ground Truth: knot
# index: 100
# 0071.wav
# Transcribed: We have often urged him to walk more and smoke glass,, Ground Truth: We have often urged him to walk more and smoke less,
# index: 101
# 0129.wav
# Transcribed: side, Ground Truth: side
# index: 102
# 0038.wav
# Transcribed: feeb, Ground Truth: feet
# index: 103
# 0160.wav
# Transcribed: Sprinkle, Ground Truth: sprinkle
# index: 104
# 0095.wav
# Transcribed: sweet, Ground Truth: meat
# index: 105
# 0044.wav
# Transcribed: He dresses himself in an ancient black frock coat., Ground Truth: he dresses himself in an ancient black frock coat,
# index: 106
# 0092.wav
# Transcribed: Try each stage you play skillfully and with zest upon our small organ., Ground Truth: Twice each day he plays skillfully and with zest upon our small organ.
# index: 107
# 0043.wav
# Transcribed: No, Ground Truth: know
# index: 108
# 0167.wav
# Transcribed: time, Ground Truth: pad
# index: 109
# 0115.wav
# Transcribed: Except in the winter when the ooze or snow or ice prevents,, Ground Truth: Except in the winter when the ooze or snow or ice prevents,
# index: 110
# 0202.wav
# Transcribed: rocks, Ground Truth: rocks
# index: 111
# 0031.wav
# Transcribed: go, Ground Truth: go
# index: 112
# 0169.wav
# Transcribed: All the big baseball players get traded., Ground Truth: All the big baseball players get traded.
# index: 113
# 0036.wav
# Transcribed: I can read., Ground Truth: I can read
#
# index: 114
# 0112.wav
# Transcribed: jagged, Ground Truth: jagged
# index: 115
# 0205.wav
# Transcribed: jango, Ground Truth: jungle
# index: 116
# 0234.wav
# Transcribed: Troop, Ground Truth: troop
# index: 117
# 0123.wav
# Transcribed: cycle, Ground Truth: cycle
# index: 118
# 0007.wav
# Transcribed: feed, Ground Truth: feed
# index: 119
# 0189.wav
# Transcribed: like, Ground Truth: light
# index: 120
# 0158.wav
# Transcribed: Srayer, Ground Truth: three
# index: 121
# 0233.wav
# Transcribed: sigh, Ground Truth: sigh
# index: 122
# 0124.wav
# Transcribed: error, Ground Truth: error
# index: 123
# 0187.wav
# Transcribed: Worf, Ground Truth: wish
# index: 124
# 0156.wav
# Transcribed: talk, Ground Truth: pot
# index: 125
# 0072.wav
# Transcribed: Luft, Ground Truth: left
# index: 126
# 0075.wav
# Transcribed: snarp, Ground Truth: knew
# index: 127
# 0009.wav
# Transcribed: pot, Ground Truth: pat
# index: 128
# 0180.wav
# Transcribed: steer, Ground Truth: steer
# index: 129
# 0151.wav
# Transcribed: fwoop, Ground Truth: fruit
# index: 130
# 0091.wav
# Transcribed: fip, Ground Truth: sip
# index: 131
# 0040.wav
# Transcribed: write, Ground Truth: rate
# index: 132
# 0118.wav
# Transcribed: Spasanos, banana oil, Ground Truth: but he always answers, "Banana oil!"
# index: 133
# 0164.wav
# Transcribed: start, Ground Truth: dot
# index: 134
# 0163.wav
# Transcribed: We're where, Ground Truth: we're
# index: 135
# 0096.wav
# Transcribed: sworn, Ground Truth: swore
# index: 136
# 0047.wav
# Transcribed: store, Ground Truth: store
# index: 137
# 0208.wav
# Transcribed: Just once I got wet,, Ground Truth: Just one side got wet.
# index: 138
# 0035.wav
# Transcribed: I care., Ground Truth: I can
#
# index: 139
# 0098.wav
# Transcribed: A long, fallow moody beard clings to his chin,, Ground Truth: A long, flowing beard clings to his chin,
# index: 140
# 0049.wav
# Transcribed: flown, Ground Truth: swarm
# index: 141
# 0111.wav
# Transcribed: goat, Ground Truth: goat
# index: 142
# 0206.wav
# Transcribed: fair, Ground Truth: bear
# index: 143
# 0116.wav
# Transcribed: food, Ground Truth: feed
# index: 144
# 0201.wav
# Transcribed: Thrive, Ground Truth: sigh
# index: 145
# 0032.wav
# Transcribed: swarm, Ground Truth: swarm
# index: 146
# 0210.wav
# Transcribed: that is spitting on the field., Ground Truth: You're used to being on the field.
# index: 147
# 0107.wav
# Transcribed: rage, Ground Truth: rage
# index: 148
# 0023.wav
# Transcribed: Ralphie is nearly ninety-three years old., Ground Truth: Well, he is nearly ninety-three years old;
# index: 149
# 0024.wav
# Transcribed: trouble, Ground Truth: trouble
# index: 150
# 0217.wav
# Transcribed: I was conscious all the time., Ground Truth: I was conscious all the time.
# index: 151
# 0100.wav
# Transcribed: rike, Ground Truth: rake
# index: 152
# 0058.wav
# Transcribed: Sheik, Ground Truth: sheet
# index: 153
# 0089.wav
# Transcribed: rave, Ground Truth: rave
# index: 154
# 0172.wav
# Transcribed: I can play this weekend., Ground Truth: I can play this weekend.
# index: 155
# 0219.wav
# Transcribed: tile, Ground Truth: tile
# index: 156
# 0056.wav
# Transcribed: horn, Ground Truth: horn
# index: 157
# 0087.wav
# Transcribed: form, Ground Truth: form
# index: 158
# 0109.wav
# Transcribed: spark, Ground Truth: bug
# index: 159
# 0051.wav
# Transcribed: bath, Ground Truth: bat
# index: 160
# 0080.wav
# Transcribed: He slowly takes a short walk in the open air each day., Ground Truth: he slowly takes a short walk in the open air each day.
# index: 161
# 0175.wav
# Transcribed: write, Ground Truth: write
# index: 162
# 0064.wav
# Transcribed: Knew, Ground Truth: knee
# index: 163
# 0140.wav
# Transcribed: hate, Ground Truth: hate
# index: 164
# 0191.wav
# Transcribed: tithe, Ground Truth: tie
# index: 165
# 0018.wav
# Transcribed: Shrip, Ground Truth: ship
# index: 166
# 0147.wav
# Transcribed: I swear, Ground Truth: sway
# index: 167
# 0196.wav
# Transcribed: Their house is grey and white., Ground Truth: Their house is grey and white.
# index: 168
# 0063.wav
# Transcribed: car, Ground Truth: car
# index: 169
# 0149.wav
# Transcribed: shoot, Ground Truth: shoot
# index: 170
# 0198.wav
# Transcribed: Nothing has been to do with innocence., Ground Truth: Nothing is as offensive as innocence.
# index: 171
# 0011.wav
# Transcribed: Okay., Ground Truth: [relax your mouth in its normal position]
# index: 172
# 0135.wav
# Transcribed: Why have a voice over silly items?, Ground Truth: Why yell or worry over silly items?
# index: 173
# 0222.wav
# Transcribed: One validated I was a school district., Ground Truth: One validated acts of school districts.
# index: 174
# 0132.wav
# Transcribed: loop, Ground Truth: loop
# index: 175
# 0225.wav
# Transcribed: stop, Ground Truth: bat
# index: 176
# 0016.wav
# Transcribed: Fair, Ground Truth: fair
# index: 177
# 0117.wav
# Transcribed: The quick brown fox jumps over the lazy dog., Ground Truth: The quick brown fox jumps over the lazy dog.
# index: 178
# 0200.wav
# Transcribed: snoop, Ground Truth: snoop
# index: 179
# 0033.wav
# Transcribed: serve, Ground Truth: share
# index: 180
# 0034.wav
# Transcribed: giving those who are observing a pronounced feeling of the utmost respect., Ground Truth: giving those who observe him a pronounced feeling of the utmost respect.
# index: 181
# 0099.wav
# Transcribed: dark, Ground Truth: dark
# index: 182
# 0048.wav
# Transcribed: chair, Ground Truth: chair
# index: 183
# 0110.wav
# Transcribed: for, Ground Truth: for
# index: 184
# 0207.wav
# Transcribed: soup, Ground Truth: suit
# index: 185
# 0162.wav
# Transcribed: war, Ground Truth: were
# index: 186
# 0097.wav
# Transcribed: up, Ground Truth: up
# index: 187
# 0046.wav
# Transcribed: Tear, Ground Truth: tear [as in "tear up that paper"]
# index: 188
# 0209.wav
# Transcribed: pile, Ground Truth: pile
# index: 189
# 0090.wav
# Transcribed: bone, Ground Truth: warm
# index: 190
# 0041.wav
# Transcribed: do, Ground Truth: knew
# index: 191
# 0119.wav
# Transcribed: true, Ground Truth: two
# index: 192
# 0165.wav
# Transcribed: soup, Ground Truth: suit
# index: 193
# 0074.wav
# Transcribed: beat, Ground Truth: beat
# index: 194
# 0008.wav
# Transcribed: out for, Ground Truth: alpha
# index: 195
# 0181.wav
# Transcribed: bam, Ground Truth: bad
# index: 196
# 0150.wav
# Transcribed: Five years gets higher or lower than Nancy's., Ground Truth: Are your grades higher or lower than Nancy's?
# index: 197
# 0186.wav
# Transcribed: Charlie, Ground Truth: charlie
# index: 198
# 0240.wav
# Transcribed: Explore, Ground Truth: explore
# index: 199
# 0157.wav
# Transcribed: spook, Ground Truth: boot
# index: 200
# 0073.wav
# Transcribed: born, Ground Truth: born
# index: 201
# 0001.wav
# Transcribed: Pah-Ah-Kah-Kah Pah-Chah-Kah Pah-Chah-Kah Pah-Chah-Kah, Ground Truth: [say 'Pah-Tah-Kah' repeatedly]
# index: 202
# 0188.wav
# Transcribed: age, Ground Truth: ate
# index: 203
# 0159.wav
# Transcribed: play, Ground Truth: play
# index: 204
# 0232.wav
# Transcribed: James may have more money by working hard., Ground Truth: Jane may earn more money by working hard.
# index: 205
# 0125.wav
# Transcribed: of, Ground Truth: of
# index: 206
# 0235.wav
# Transcribed: brute, Ground Truth: root
# index: 207
# 0122.wav
# Transcribed: Trace, Ground Truth: trace
# index: 208
# 0006.wav
# Transcribed: grow, Ground Truth: grow
# index: 209
# 0133.wav
# Transcribed: here, Ground Truth: here
# index: 210
# 0224.wav
# Transcribed: fake, Ground Truth: fate
# index: 211
# 0017.wav
# Transcribed: feet, Ground Truth: feet
# index: 212
# 0148.wav
# Transcribed: shelved, Ground Truth: shout
# index: 213
# 0199.wav
# Transcribed: sleigh, Ground Truth: slay
# index: 214
# 0010.wav
# Transcribed: farm, Ground Truth: farm
# index: 215
# 0134.wav
# Transcribed: area, Ground Truth: area
# index: 216
# 0223.wav
# Transcribed: love, Ground Truth: mere
# index: 217
# 0146.wav
# Transcribed: slip, Ground Truth: slip
# index: 218
# 0197.wav
# Transcribed: Nothing is as offensive as ignorance., Ground Truth: Nothing is as offensive as ignorance
#
# index: 219
# 0062.wav
# Transcribed: When he speaks, his voice is just a bit cracked and quivers a trifle., Ground Truth: When he speaks, his voice is just a bit cracked and quivers a trifle.
# index: 220
# 0065.wav
# Transcribed: No, Ground Truth: no
# index: 221
# 0141.wav
# Transcribed: This was easy for us., Ground Truth: This was easy for us.
# index: 222
# 0190.wav
# Transcribed: do, Ground Truth: knew
# index: 223
# 0019.wav
# Transcribed: park, Ground Truth: park
# index: 224
# 0108.wav
# Transcribed: Hair, Ground Truth: hair
# index: 225
# 0050.wav
# Transcribed: eeeel, Ground Truth: [say 'Eee' in a very high pitch]
# index: 226
# 0081.wav
# Transcribed: storm, Ground Truth: storm
# index: 227
# 0174.wav
# Transcribed: This gave me off on the structure., Ground Truth: They carried me off on the stretcher.
# index: 228
# 0173.wav
# Transcribed: I feel I can play this weekend., Ground Truth: I feel I can play this weekend.
# index: 229
# 0218.wav
# Transcribed: prior, Ground Truth: prior
# index: 230
# 0057.wav
# Transcribed: lead, Ground Truth: lead [as in "I will lead you"]
# index: 231
# 0086.wav
# Transcribed: glow, Ground Truth: glow
# index: 232
# 0025.wav
# Transcribed: chair, Ground Truth: chair
# index: 233
# 0216.wav
# Transcribed: slow, Ground Truth: slip
# index: 234
# 0101.wav
# Transcribed: race, Ground Truth: race
# index: 235
# 0059.wav
# Transcribed: prada, Ground Truth: beta
# index: 236
# 0088.wav
# Transcribed: form, Ground Truth: warm
# index: 237
# 0211.wav
# Transcribed: forwards, Ground Truth: forward
# index: 238
# 0106.wav
# Transcribed: Don't ask me to carry an oily rag like that., Ground Truth: Don't ask me to carry an oily rag like that.
# index: 239
# 0022.wav
# Transcribed: back, Ground Truth: bit

# %%
from IPython.display import Audio
Audio(os.path.join(audio_dir_path, file_lists[177]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
